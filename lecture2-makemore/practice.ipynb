# %% [markdown]
# # Lecture 2 — Dead-Reckoning Practice
#
# Close makemore.ipynb. Rebuild from memory.
# No notes. No looking back.
#
# **Checklist:**
# - [ ] Load names.txt, build stoi/itos
# - [ ] Build 27x27 bigram count matrix N
# - [ ] Normalize to probabilities P
# - [ ] Sample 5 names from P
# - [ ] Compute NLL loss on training set
# - [ ] Build neural net: one-hot -> W -> logits -> softmax
# - [ ] Training loop, watch loss go down
# - [ ] Sample 5 names from trained net

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# START HERE — rebuild everything from memory
