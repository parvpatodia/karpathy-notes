# %% [markdown]
# # L3 Dead-Reckoning — makemore MLP
#
# Close `makemore_mlp.ipynb`. Close the video. Rebuild the full MLP from memory.
#
# **Checklist — do these without looking:**
# - [ ] stoi / itos from names.txt
# - [ ] `build_dataset()` with block_size=3 sliding window
# - [ ] 80/10/10 train/dev/test split
# - [ ] C, W1, b1, W2, b2 initialization (know the shapes)
# - [ ] Forward pass: embed → concat → tanh → logits → cross_entropy
# - [ ] Minibatch training loop with lr decay
# - [ ] `split_loss()` eval function with `@torch.no_grad()`
# - [ ] 2D embedding visualization
# - [ ] Sampling loop
#
# If you get stuck on a shape, work it out on paper first. Don't open the lecture notebook.

# %%
# YOUR CODE — build everything from scratch
